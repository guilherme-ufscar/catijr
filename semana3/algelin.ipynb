# %% [markdown]
# Vetor = Sentido, direção e valor (tamanho), ex: V = [1,2,3] ([x,y,z])
#
# a = [1,2] b = [2,1], vetor ba = [2-1,1-2] = [1,-1]. Soma a+b = [3,3]

# %% [markdown]
# Matriz = tabela de numeros separada em linha e coluna. Amxn, m = qtd de linha, n = qtd de coluna, Aij (elemento da matriz baseado na posição linha e coluna)

# %% [markdown]
# Tensores = dizer a dimensão<br>
# escalar (apenas um numero)<br>
# vetor (lista de numeros)<br>
# matriz (tabela de numeros)
