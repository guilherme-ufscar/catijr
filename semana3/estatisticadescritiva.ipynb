# %% [markdown]
# População = Conjunto completo das amostras (o todo)<br>
# Amostra = Parcela da população, uma parte de um todo (usado quando não é necessario analisar todo mundo ou não há como)

# %% [markdown]
# Media, moda e mediana.
# <br><br>
# Média = soma de todos elementos/qtd<br>
# Moda = valor que mais se repete<br>
# Mediana = valor que aparece no meio, central, em um conjunto de dados ordenado
